# %% [markdown]
# <a href="https://colab.research.google.com/github/jonathanahc/Practicas/blob/main/Pr%C3%A1ctica_2_Expresiones_Regulares.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Monta Google Colab con Drive
from google.colab import drive
drive.mount('/content/drive')

#Importa la librería Re
import re
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Abre el archivo de texto
informe = open('/content/drive/MyDrive/ClassFiles/informe_acciones.txt', encoding='latin-1')
#Crea una lista para la carga de los datos
valores = []

# %%
#Con el ciclo For, se realiza un recorrido de todo el archivo de texto
for i in informe:
  #Elimina los saltos de línea y espacios en blanco
  i = i.rstrip()
  #Busca todos los caracteres que estén con Valor actual
  if re.search('^Valor actual:.+$', i):
    #Reemplaza la cadena Valor actual por un espacio en blanco
    i = re.sub(r'Valor actual: ', '', i)
    #Inserta los datos en la lista
    valores.append(i)
#Imprime la lista
print(valores)
# Out:
# ['$446.52', '$520.22', '$552.66', '$722.88', '$611.0', '$391.37', '$1101.2', '$242.94', '$1297.49', '$750.8', '$1376.93', '$718.31', '$1154.06', '$650.18', '$969.01', '$1399.02', '$1096.73', '$786.31', '$1497.06', '$1303.97', '$604.43', '$1385.17', '$104.28', '$871.25', '$1485.74', '$553.89', '$626.23', '$962.15', '$1370.8', '$1263.42', '$778.08', '$847.49', '$506.96', '$474.65', '$1403.22', '$764.77', '$1364.0', '$663.52', '$309.24', '$674.69', '$208.52', '$744.3', '$337.03', '$843.9', '$876.17', '$301.54', '$1499.69', '$872.91', '$644.07', '$879.08', '$233.42', '$1300.64', '$986.34', '$1341.26', '$1394.03', '$1222.2', '$752.72', '$1165.03', '$1267.75', '$1219.67', '$1438.39', '$493.02', '$1351.05', '$1060.39', '$1041.76', '$157.95', '$689.0', '$115.38', '$981.45', '$522.87', '$1066.61', '$146.53', '$356.17', '$169.99', '$109.71', '$1407.28', '$531.69', '$1110.14', '$702.28', '$632.08', '$590.46', '$1223.24', '$1362.9', '$268.73', '$785.56', '$277.23', '$1330.06', '$1054.25', '$1236
# ...
