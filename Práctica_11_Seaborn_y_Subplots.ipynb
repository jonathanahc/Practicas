# %% [markdown]
# <a href="https://colab.research.google.com/github/jonathanahc/Practicas/blob/main/Pr%C3%A1ctica_11_Seaborn_y_Subplots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = sns.load_dataset("penguins")
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
plt.subplots(nrows=2, ncols=2, figsize=(10, 10))

sns.histplot(data=df, x="flipper_length_mm", ax=plt.subplot(2, 2, 1))
plt.subplot(2, 2, 1)

sns.boxplot(data=df, x="species", y="body_mass_g", ax=plt.subplot(2, 2, 2))
plt.subplot(2, 2, 2)

sns.scatterplot(data=df, x="flipper_length_mm", y="body_mass_g", ax=plt.subplot(2, 2, 3))
plt.subplot(2, 2, 3)

sns.violinplot(data=df, x="species", y="body_mass_g", ax=plt.subplot(2, 2, 4))
plt.subplot(2, 2, 4)

plt.tight_layout()
plt.show()
